# %%
# !pip install -r requirement.txt
# Out:
# ...
#   Using cached attrs-21.4.0-py2.py3-none-any.whl.metadata (9.8 kB)
# ...
#   Using cached jsonschema-4.4.0-py3-none-any.whl.metadata (7.5 kB)
# ...
#   Using cached jupyter_client-7.1.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached jupyter_core-4.9.2-py3-none-any.whl.metadata (870 bytes)
# ...
#   Using cached mistune-0.8.4-py2.py3-none-any.whl.metadata (8.5 kB)
# ...
#   Using cached nbconvert-6.4.2-py3-none-any.whl.metadata (5.8 kB)
# ...
#   Using cached nbformat-5.1.3-py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached numpy-1.22.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.0 kB)
# ...
#   Using cached opencv_python-4.5.5.62-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# ...
#   Using cached packaging-21.3-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached protobuf-3.19.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (806 bytes)
# ...
#   Using cached pyzmq-22.3.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (5.0 kB)
# ...

# %%
# !nvidia-smi
# Out:
# Tue Dec 17 22:40:02 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.54.03              Driver Version: 535.54.03    CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla P100-PCIE-12GB           On  | 00000000:04:00.0 Off |                    0 |
# | N/A   24C    P0              24W / 250W |      0MiB / 12288MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !nvcc -V
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Tue_May__3_18:49:52_PDT_2022
# Cuda compilation tools, release 11.7, V11.7.64
# Build cuda_11.7.r11.7/compiler.31294372_0

# %%
# !pip install torch==1.11.0+cu113 torchvision==0.12.0+cu113 torchaudio==0.11.0+cu113 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...

# %%
# !pip install ultralytics onnx onnxruntime-gpu
# Out:
# ...
#   Using cached numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.1/899.1 kB 23.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 78.4 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.1/157.1 MB 27.6 MB/s eta 0:00:0000:0100:01
# Using cached numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 94.6 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 86.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.62.3
#     Uninstalling tqdm-4.62.3:
#       Successfully uninstalled tqdm-4.62.3
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.4
#     Uninstalling protobuf-3.19.4:
#       Successfully uninstalled protobuf-3.19.4
#   Attempting uninstall: numpy
# ...

# %%
# !pip install argparse

# %%
# !pip install timm
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 46.6 MB/s eta 0:00:00
# ...

# %%
# !python vis_label.py --version v1.0-mini dataset/nuScenes
# Out:
# 100%|███████████████████████████████████████████| 81/81 [18:40<00:00, 13.83s/it]

# %%
# !python vis_segmentation_label.py dataset/nuScenes/ --version v1.0-mini
# Out:
# 100%|███████████████████████████████████████████| 81/81 [01:14<00:00,  1.09it/s]

# %%
# !mkdir -p ~/torch_cache/hub/checkpoints

# %%
# !chmod 755 ~/torch_cache
# !chmod 755 ~/torch_cache/hub
# !chmod 755 ~/torch_cache/hub/checkpoints

# %%
# !python train.py --instance_seg --direction_pred --version v1.0-mini --dataroot dataset/nuScenes
# Out:
# Loaded pretrained weights for efficientnet-b0
# /home/018173194/.local/lib/python3.8/site-packages/torch/functional.py:568: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2228.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# TRAIN[  0]: [   9/79]    Time:  0.8143    Loss:  2.3845    IOU: [0.017 0.000 0.000]
# TRAIN[  0]: [  19/79]    Time:  0.8534    Loss:  1.4945    IOU: [0.000 0.000 0.000]
# TRAIN[  0]: [  29/79]    Time:  0.8127    Loss:  1.2774    IOU: [0.000 0.000 0.000]
# TRAIN[  0]: [  39/79]    Time:  0.8305    Loss:  1.4866    IOU: [0.000 0.000 0.000]
# TRAIN[  0]: [  49/79]    Time:  0.8065    Loss:  1.2780    IOU: [0.000 0.000 0.000]
# TRAIN[  0]: [  59/79]    Time:  0.7923    Loss:  1.2127    IOU: [0.000 0.000 0.000]
# TRAIN[  0]: [  69/79]    Time:  0.8080    Loss:  1.3850    IOU: [0.000 0.000 0.000]
# ...

# %%
# !mkdir -p ~/torch_cache
# !mkdir -p ~/huggingface_cache
# !chmod 755 ~/torch_cache
# !chmod 755 ~/huggingface_cache

# %%
# !python train.py --instance_seg --direction_pred --version v1.0-mini --dataroot dataset/nuScenes
# Out:
# Loaded pretrained weights for efficientnet-b0
# /home/018173194/.local/lib/python3.8/site-packages/torch/functional.py:568: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2228.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# TRAIN[  0]: [   9/160] Time:  1.5759 Loss:  2.2419 IOU: [0.038 0.027 0.055]
# TRAIN[  0]: [  19/160] Time:  1.6982 Loss:  2.2232 IOU: [0.051 0.042 0.072]
# TRAIN[  0]: [  29/160] Time:  1.3326 Loss:  1.4322 IOU: [0.009 0.000 0.025]
# TRAIN[  0]: [  39/160] Time:  1.5354 Loss:  1.3825 IOU: [0.000 0.013 0.009]
# TRAIN[  0]: [  49/160] Time:  1.4964 Loss:  1.0549 IOU: [0.000 0.000 0.000]
# TRAIN[  0]: [  59/160] Time:  1.4888 Loss:  0.7082 IOU: [0.000 0.000 0.000]
# TRAIN[  0]: [  69/160] Time:  1.5557 Loss:  0.8046 IOU: [0.000 0.000 0.000]
# TRAIN[  0]: [  79/160] Time:  1.3699 Loss:  0.7659 IOU: [0.000 0.000 0.000]
# ...

# %%
# !python train.py --instance_seg --direction_pred --version v1.0-mini --dataroot dataset/nuScenes --export_onnx --onnx_path ./runs/hdmapnet.onnx
# Out:
# Loaded pretrained weights for efficientnet-b0
# /home/018173194/.local/lib/python3.8/site-packages/torch/functional.py:568: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2228.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# TRAIN[  0]: [   9/160] Time:  1.5500 Loss:  2.2731 IOU: [0.051 0.018 0.102]
# TRAIN[  0]: [  19/160] Time:  1.5397 Loss:  2.3035 IOU: [0.051 0.028 0.062]
# TRAIN[  0]: [  29/160] Time:  1.5098 Loss:  2.1858 IOU: [0.033 0.027 0.075]
# TRAIN[  0]: [  39/160] Time:  1.5032 Loss:  1.8143 IOU: [0.055 0.020 0.067]
# TRAIN[  0]: [  49/160] Time:  1.4389 Loss:  1.5651 IOU: [0.077 0.000 0.089]
# TRAIN[  0]: [  59/160] Time:  1.4491 Loss:  1.6623 IOU: [0.037 0.028 0.095]
# TRAIN[  0]: [  69/160] Time:  1.3829 Loss:  1.5914 IOU: [0.028 0.032 0.068]
# TRAIN[  0]: [  79/160] Time:  1.4141 Loss:  1.5116 IOU: [0.036 0.015 0.104]
# ...

# %%
# !python export_gt_to_json.py
# Out:
# 100%|███████████████████████████████████████████| 81/81 [00:15<00:00,  5.23it/s]
# exported to submission.json

# %%
# !python export_gt_to_json.py
# Out:
# 100%|███████████████████████████████████████████| 81/81 [00:15<00:00,  5.18it/s]
# exported to submission.json

# %%
# !python export_gt_to_json.py --raster
# Out:
# 100%|███████████████████████████████████████████| 81/81 [00:16<00:00,  4.93it/s]
# exported to submission.json

# %%
# !python export_gt_to_json.py --raster
# Out:
# 100%|███████████████████████████████████████████| 81/81 [00:16<00:00,  4.88it/s]
# exported to submission.json

# %%
#This need not be necessarily run, but you can try it if needed
# !export TORCH_HOME=~/torch_cache
# !mkdir -p ~/torch_cache

# %%
# !python evaluate.py --result_path HDMapNet/submission.json --model HDMapNet_cam --modelf ./runs/model28.pt --dataroot dataset/nuScenes/ --version v1.0-mini --instance_seg --direction_pred
# Out:
# Loaded pretrained weights for efficientnet-b0
# /home/018173194/.local/lib/python3.8/site-packages/torch/functional.py:568: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2228.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 100%|███████████████████████████████████████████| 21/21 [00:10<00:00,  2.10it/s]
# tensor([0.8648, 0.0883, 0.0037, 0.0372])

# %%
# !python evaluate.py --result_path HDMapNet/submission.json --model HDMapNet_cam --modelf ./runs/model29.pt --dataroot dataset/nuScenes/ --version v1.0-mini --instance_seg --direction_pred
# Out:
# Loaded pretrained weights for efficientnet-b0
# /home/018173194/.local/lib/python3.8/site-packages/torch/functional.py:568: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2228.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 100%|███████████████████████████████████████████| 21/21 [00:18<00:00,  1.13it/s]
# tensor([0.8754, 0.0572, 0.0000, 0.0018])

# %%
# !python export_pred_to_json.py --modelf ./runs/model28.pt
# Out:
# Loaded pretrained weights for efficientnet-b0
# /home/018173194/.local/lib/python3.8/site-packages/torch/functional.py:568: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2228.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 100%|███████████████████████████████████████████| 21/21 [00:29<00:00,  1.42s/it]

# %%
# !python export_pred_to_json.py --modelf ./runs/model29.pt
# Out:
# Loaded pretrained weights for efficientnet-b0
# /home/018173194/.local/lib/python3.8/site-packages/torch/functional.py:568: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2228.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 100%|███████████████████████████████████████████| 21/21 [00:35<00:00,  1.68s/it]

# %%
# !python evaluate_json.py --result_path submission.json --version v1.0-mini --eval_set mini_val
# Out:
# running eval...
#   0%|                                                    | 0/21 [00:00<?, ?it/s]/home/018173194/HDMapNet/evaluation/AP.py:43: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   i, j = (idx // CD.shape[1]).item(), (idx % CD.shape[1]).item()
# 100%|███████████████████████████████████████████| 21/21 [00:23<00:00,  1.13s/it]
# {'iou': tensor([0.1378, 0.1361, 0.1365], device='cuda:0'), 'CD_pred': tensor([0.0011, 0.0013, 0.0013], device='cuda:0'), 'CD_label': tensor([0.2563, 0.2567, 0.2530], device='cuda:0'), 'CD': tensor([0.2254, 0.2261, 0.2228], device='cuda:0'), 'Average_precision': tensor([[1., 1., 1.],
#         [1., 1., 1.],
# ...

# %%
# !python vis_pred_gif_combined.py --modelf ./runs/model28.pt --instance_seg --direction_pred
# Out:
# Loaded pretrained weights for efficientnet-b0
# /home/018173194/.local/lib/python3.8/site-packages/torch/functional.py:568: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2228.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# saving eval000000_000.jpg
# saving eval000000_001.jpg
# saving eval000000_002.jpg
# saving eval000000_003.jpg
# saving eval000001_000.jpg
# saving eval000001_001.jpg
# saving eval000001_002.jpg
# saving eval000001_003.jpg
# saving eval000002_000.jpg
# saving eval000002_001.jpg
# saving eval000002_002.jpg
# saving eval000002_003.jpg
# saving eval000003_000.jpg
# saving eval000003_001.jpg
# saving eval000003_002.jpg
# saving eval000003_003.jpg
# saving eval000004_000.jpg
# saving eval000004_001.jpg
# saving eval000004_002.jpg
# saving eval000004_003.jpg
# saving eval000005_000.jpg
# saving eval000005_001.jpg
# ...

# %%
# !python vis_pred_gif_combined.py --modelf ./runs/model29.pt --instance_seg --direction_pred
# Out:
# Loaded pretrained weights for efficientnet-b0
# /home/018173194/.local/lib/python3.8/site-packages/torch/functional.py:568: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2228.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# saving eval000000_000.jpg
# saving eval000000_001.jpg
# saving eval000000_002.jpg
# saving eval000000_003.jpg
# saving eval000001_000.jpg
# saving eval000001_001.jpg
# saving eval000001_002.jpg
# saving eval000001_003.jpg
# saving eval000002_000.jpg
# saving eval000002_001.jpg
# saving eval000002_002.jpg
# saving eval000002_003.jpg
# saving eval000003_000.jpg
# saving eval000003_001.jpg
# saving eval000003_002.jpg
# saving eval000003_003.jpg
# saving eval000004_000.jpg
# saving eval000004_001.jpg
# saving eval000004_002.jpg
# saving eval000004_003.jpg
# saving eval000005_000.jpg
# saving eval000005_001.jpg
# ...
